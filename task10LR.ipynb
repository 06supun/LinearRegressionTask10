# %%
import pandas as pd
df = pd.read_csv("country_temperature.csv")

# %%
X = df[['Year']].values
y = df['AvgTemperature'].values

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X, y)
# Out:
# LinearRegression()

# %%
import numpy as np

X_future = np.arange(2022, 2050).reshape(-1, 1) # create feature matrix for future years
y_pred = lr.predict(X_future) # predict global average temperatures for future years

# %%
import matplotlib.pyplot as plt

plt.scatter(X, y, color='b') # plot the training data
plt.plot(X_future, y_pred, color='r') # plot the predicted data
plt.title('Global Average Temperature Linear Regression')
plt.xlabel('Year')
plt.ylabel('Temperature (°C)')
plt.show()
